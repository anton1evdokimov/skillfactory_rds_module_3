# %% [markdown]
# # Загрузка Pandas и очистка данных

# %%
import pandas as pd
import numpy as np
import re
import math
from datetime import datetime

# %%
df = pd.read_csv('main_task.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      40000 non-null  object
#  1   City               40000 non-null  object
#  2   Cuisine Style      30717 non-null  object
#  3   Ranking            40000 non-null  float64
#  4   Rating             40000 non-null  float64
#  5   Price Range        26114 non-null  object
#  6   Number of Reviews  37457 non-null  float64
#  7   Reviews            40000 non-null  object
#  8   URL_TA             40000 non-null  object
#  9   ID_TA              40000 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 3.1+ MB

# %%
# Ваш код по очистке данных и генерации новых признаков
# При необходимости добавьте ячейки

# 1. Где количестов отзывов не указано пишем 0
df['Number of Reviews'].fillna(0, inplace=True)
#print(df['Price Range'].unique())

cuisine = set()
# \w	[0-9a-z_] любая цифра, буква или знак подчеркивания
# + - одно или болле вхождений
# * - ноль или болле вхождений
# \s [ \t\v\r\n\f] пробельный символ
df['Cuisine Style'].fillna('European', inplace=True)
df['Cuisine Style'] = df['Cuisine Style'].str.findall('\w+\s*\w*\s*\w*')

cuisines = set()  # создаём пустое множество для хранения уникальных значений кухонь
for styles in df['Cuisine Style']:
    for item in styles:
        cuisines.add(item)


def find_item(cell):
    if item in cell:
        return 1
    return 0


for item in cuisines:
    df[item] = df['Cuisine Style'].apply(find_item)

# Добавляем признак - количество кухонь
df['CuisineCount'] = df['Cuisine Style'].apply(lambda x: len(x))

sum = df.CuisineCount.sum()
length = len(df.CuisineCount)
sum/length

#pat = re.compile('\w+\s*\w*\s*\w*')
#cuisine_styles = df['Cuisine Style'].dropna().apply(lambda x: ['default'] if pd.isnull(x) else pat.findall(x))
# cuisine_styles.explode().value_counts(ascending=False)
#
# для One-Hot Encoding в pandas есть готовая функция - get_dummies. Особенно радует параметр dummy_na
#df = pd.get_dummies(df, columns=['City', 'Price Range'], dummy_na=True)
df.corr()
# Out:
#                     Ranking    Rating  Number of Reviews  Central American  \
# Ranking            1.000000 -0.368371          -0.222072         -0.018318
# Rating            -0.368371  1.000000           0.026924          0.000929
# Number of Reviews -0.222072  0.026924           1.000000          0.044804
# Central American  -0.018318  0.000929           0.044804          1.000000
# Romanian           0.001863  0.004896          -0.005056         -0.000920
# ...                     ...       ...                ...               ...
# Afghani            0.003787  0.004233          -0.003223         -0.001365
# Arabic            -0.008968  0.006661          -0.005665         -0.002079
# Mexican           -0.001241 -0.021004           0.005467          0.347267
# Ethiopian         -0.006911  0.013041           0.000045         -0.001887
# CuisineCount      -0.320111  0.120134           0.405577          0.079427
#
# ...

# %%
def reviews_date(rew, count):
    try:
        date = re.findall(r'\d\d?/\d\d?/\d+', rew)
        
        lenDate = len(date)
        if count == 3:
            return lenDate
        if lenDate == 0:
            return np.nan
        if count == 1:
            #return pd.to_datetime(date[0])
            return math.log(pd.to_datetime(date[0]).timestamp())
        elif lenDate == 2:
            #return pd.to_datetime(date[1])
            return math.log(pd.to_datetime(date[1]).timestamp())
        else:
            return np.nan
    except Exception:
        return np.nan
    
    
def len_reviews(item):
    try:
        len(re.findall(r'[a-zA-Z]', item))
    except Exception:
        return np.nan

    
def preproc_data(df_input):
    '''includes several functions to pre-process the predictor data.'''
    
    df_output = df_input.copy()
    
    # ################### 1. Предобработка ############################################################## 
    # убираем не нужные для модели признаки
    df_output.drop(['Restaurant_id','ID_TA',], axis = 1, inplace=True)
    
    
    # ################### 2. NAN ############################################################## 
    # Далее заполняем пропуски, вы можете попробовать заполнением средним или средним по городу и тд...
    df_output['Number of Reviews'].fillna(0, inplace=True)
    df_output['Cuisine Style'].fillna('European', inplace=True)
    
    citys = df_output.City.value_counts()
    df_output.City = df_output.City.apply(lambda x: x if citys[x]>100 else np.nan)
    # ################### 3. Encoding ############################################################## 
    # для One-Hot Encoding в pandas есть готовая функция - get_dummies. Особенно радует параметр dummy_na
    df_output = pd.get_dummies(df_output, columns=['City', 'Price Range'], dummy_na=True)

    # ################### 4. Feature Engineering ####################################################
    cuisine = set()
    
    df_output['Cuisine Style'] = df_output['Cuisine Style'].str.findall('\w+\s*\w*\s*\w*')

    cuisines = set()  # создаём пустое множество для хранения уникальных значений кухонь
    for cuisinesList in df_output['Cuisine Style']:
        for cuisine in cuisinesList:
            cuisines.add(cuisine)


    def find_item(cell):
        if item in cell:
            return 1
        return 0


    for item in cuisines:
        df_output[item] = df_output['Cuisine Style'].apply(find_item)

    # Добавляем признак - количество кухонь
    df_output['Cuisine Count'] = df_output['Cuisine Style'].apply(lambda x: len(x))
    
    df_output['Reviews_first'] = df_output['Reviews'].apply(lambda x: reviews_date(x, 1))
    df_output['Reviews_second'] = df_output['Reviews'].apply(lambda x: reviews_date(x, 2))
    df_output['Reviews_Count'] = df_output['Reviews'].apply(lambda x: reviews_date(x, 3))
    
    df_output['Reviews_first'].fillna(df_output['Reviews_first'].mean(), inplace=True)
    df_output['Reviews_second'].fillna(df_output['Reviews_second'].mean(), inplace=True)
    df_output['Reviews_Count'].fillna(0, inplace=True)
    
    # ################### 5. Clean #################################################### 
    # убираем признаки которые еще не успели обработать, 
    # модель на признаках с dtypes "object" обучаться не будет, просто выберим их и удалим
    object_columns = [s for s in df_output.columns if df_output[s].dtypes == 'object']
    df_output.drop(object_columns, axis = 1, inplace=True)
    return df_output

# %% [markdown]
# # Разбиваем датафрейм на части, необходимые для обучения и тестирования модели

# %%
# всегда фиксируйте RANDOM_SEED, чтобы ваши эксперименты были воспроизводимы!
RANDOM_SEED = 42
# зафиксируем версию пакетов, чтобы эксперименты были воспроизводимы:
# !pip freeze > requirements.txt

# Х - данные с информацией о ресторанах, у - целевая переменная (рейтинги ресторанов)
df_preproc = preproc_data(pd.read_csv('main_task.csv'))

X = df_preproc.drop(['Rating'], axis = 1)
y = df_preproc['Rating']

# Загружаем специальный инструмент для разбивки:
from sklearn.model_selection import train_test_split
# Наборы данных с меткой "train" будут использоваться для обучения модели, "test" - для тестирования.
# Для тестирования мы будем использовать 25% от исходного датасета.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=RANDOM_SEED)
df_preproc.corr()
# Out:
#                     Ranking    Rating  Number of Reviews  City_Amsterdam  \
# Ranking            1.000000 -0.368371          -0.222072       -0.094372
# Rating            -0.368371  1.000000           0.026924        0.034535
# Number of Reviews -0.222072  0.026924           1.000000        0.013348
# City_Amsterdam    -0.094372  0.034535           0.013348        1.000000
# City_Athens       -0.095177  0.044792          -0.010741       -0.021098
# ...                     ...       ...                ...             ...
# Ethiopian         -0.006911  0.013041           0.000045        0.004083
# Cuisine Count     -0.320111  0.120134           0.405577        0.063350
# Reviews_first     -0.180685  0.090483           0.195188        0.043373
# Reviews_second    -0.178401  0.087947           0.218467        0.046139
# Reviews_Count     -0.139749  0.020524           0.213904        0.061958
#
#                    City_Athens  City_Barcelona  City_Berlin  City_Bratislava  \
# ...

# %% [markdown]
# # Создаём, обучаем и тестируем модель

# %%
# Импортируем необходимые библиотеки:
# инструмент для создания и обучения модели
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics  # инструменты для оценки точности модели
# Создаём модель
regr = RandomForestRegressor(
    n_estimators=100, verbose=1, n_jobs=-1, random_state=RANDOM_SEED)

# Обучаем модель на тестовом наборе данных
regr.fit(X_train, y_train)

# Используем обученную модель для предсказания рейтинга ресторанов в тестовой выборке.
# Предсказанные значения записываем в переменную y_pred
y_pred = regr.predict(X_test)
# Сравниваем предсказанные значения (y_pred) с реальными (y_test), и смотрим насколько они в среднем отличаются
# Метрика называется Mean Absolute Error (MAE) и показывает среднее отклонение предсказанных значений от фактических.
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   13.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# MAE: 0.207898
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
